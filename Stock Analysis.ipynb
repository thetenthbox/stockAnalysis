# %% [markdown]
# # Analysis of PLC financials listed on the London Stock Exchange
#
#
#
# This pipeline aims to scrape key company financials off the London Stock Exchange website. The aim is to create a large database of PLCs and their financial data including historical stock prices to conduct in-depth ML/DL analysis into what creates a good long term stock pick.
#
#
# Importing libraries

# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import requests
import html
import json

# %% [markdown]
# ## Example of scraping data - STAN
#
# Scraping company financials from the LSE website. This first example collects data on Standard Chartered PLC (STAN)

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.212 Safari/537.36'}
url = 'https://www.londonstockexchange.com/stock/{}/{}'

stock = 'STAN/standard-chartered-plc'
info = 'fundamentals'

full_url = url.format(stock, info)

print(full_url)

r = requests.get(full_url)
soup = BeautifulSoup(r.text, 'lxml')
data = json.loads(soup.select_one('#ng-lseg-state').string.replace('&q;','"'))
#print(len(data['sortedComponents']['content']))
#print(data['sortedComponents']['content'][1]['status']['childComponents'][1]['content'].keys())
fundamentals = data['sortedComponents']['content'][1]['status']['childComponents'][1]['content']['fundamentals']

company_data = {}

for key1, value1 in fundamentals.items():
    #print(key1)
    for key2,value2 in value1.items():
           
            for item in value2:
                
                #print(item)
                for key3, value3 in item.items():
                    if type(value3) == dict:
                        if key3 in company_data:
                            company_data[key3].append(value3['value'])
                        else:
                            company_data.setdefault(key3, [value3['value']])
            
#print(company_data)                             
columns = company_data.keys()



df = pd.DataFrame.from_dict(company_data, orient='index')
df = df.transpose()
df = df.drop_duplicates(subset='dateyearend', keep='first', inplace=False)
df.insert(0, 'Company', stock)
df
# Out:
# https://www.londonstockexchange.com/stock/STAN/standard-chartered-plc/fundamentals
#                        Company dateyearend currency totaldividend taxes  \
# 0  STAN/standard-chartered-plc  2016-12-31      USD             -     -
# 1  STAN/standard-chartered-plc  2017-12-31      USD          0.11     -
# 2  STAN/standard-chartered-plc  2018-12-31      USD          0.21     -
# 3  STAN/standard-chartered-plc  2019-12-31      USD          0.22     -
# 4  STAN/standard-chartered-plc  2020-12-31      USD          0.09     -
#
#        revenue provisionsforlosses profitforperiod pretaxprofit posttaxprofit  \
# 0  19679000000                   -      -191000000    446000000    -154000000
# 1  21377000000                   -      1268000000   2147000000    1000000000
# 2  24038000000                   -      1109000000   2307000000     868000000
# 3  25188000000                   -      2340000000   3413000000    2040000000
# 4  21050000000                   -       751000000   2401000000    1539000000
#
#    ... epsgrowthpercentual dividendcover revenuepershare pretaxprofitpershare  \
# 0  ...                   -             -          5.9633               0.1352
# 1  ...                   -        2.1364          6.4916                0.652
# 2  ...            -20.4255        0.8905           7.271               0.6978
# 3  ...            204.8128        2.5909          7.7359               1.0482
# 4  ...            -81.8042        1.1556          6.6432               0.7577
#
#   operatingmarging returnoncapitalemployed dividendyield  \
# 0                -                       -             -
# 1                -                       -        1.0609
# 2                -                       -        2.6926
# 3                -                       -        2.3395
# 4                -                       -        1.4204
#
#   dividendpersharegrowth navpershare netgearing
# 0                      -      13.307          -
# 1                      -       14.11          -
# 2                90.9091     13.6201          -
# 3                 4.7619     14.1208          -
# 4               -59.2027     13.9202          -
#
# [5 rows x 53 columns]

# %% [markdown]
# As seen, this set of code creates a dataframe containing 52 columns, data found in the fundamentals section of the STAN listing on the LSE. We shall now create a function to do this for any company. First, we need to create a main dataframe that will contain all data for every company that we scrape.

# %%
columns = company_data.keys()
empty = []
main_df = pd.DataFrame(columns=columns)
main_df.insert(0, 'Company', value = empty)

# %%
main_df
# Out:
# Empty DataFrame
# Columns: [Company, dateyearend, currency, totaldividend, taxes, revenue, provisionsforlosses, profitforperiod, pretaxprofit, posttaxprofit, otheroperatingexpenses, othernonoperatingincome, operatingprofitLoss, operatingexpenses, noninterestincome, noninterestexpense, netinterestbeforeprovisions, netinterestafterprovisions, netinterest, minorityinterests, interestincome, interestexpense, grossprofit, equityholderofparent, epsbasiccontinuinganddiscontinued, epsbasic, deprecationamortization, costofrevenue, benefitsandoperatingexpenses, belowlineadjustments, totalassets, totalnoncurrentassets, totalcurrentassets, totalliabilities, totalnoncurrentliabilities, totalcurrentliabilities, netassets, totalequity, shareholdersfunds, bsminorityinterests, retainedearnings, peratio, peg, epsgrowthpercentual, dividendcover, revenuepershare, pretaxprofitpershare, operatingmarging, returnoncapitalemployed, dividendyield, dividendpersharegrowth, navpershare, netgearing]
# Index: []
#
# [0 rows x 53 columns]

# %% [markdown]
# ## Creating a function
#
# As seen, this set of code creates a dataframe containing 52 columns, data found in the fundamentals section of the STAN listing on the LSE. We shall now create a function to do this for any company. `main_df` is the dataframe that will contain all our data

# %%
def my_scraper(stock):
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.212 Safari/537.36'}
    url = 'https://www.londonstockexchange.com/stock/{}/{}'

    
    info = 'fundamentals'

    full_url = url.format(stock, info)

    print(full_url)

    r = requests.get(full_url)
    soup = BeautifulSoup(r.text, 'lxml')
    data = json.loads(soup.select_one('#ng-lseg-state').string.replace('&q;','"'))
    #print(len(data['sortedComponents']['content']))
    #print(data['sortedComponents']['content'][1]['status']['childComponents'][1]['content'].keys())
    fundamentals = data['sortedComponents']['content'][1]['status']['childComponents'][1]['content']['fundamentals']

    company_data = {}

    for key1, value1 in fundamentals.items():
        #print(key1)
        for key2,value2 in value1.items():
           
            for item in value2:
                
                    #print(item)
                    for key3, value3 in item.items():
                            if type(value3) == dict:
                                if key3 in company_data:
                                    company_data[key3].append(value3['value'])
                                else:
                                    company_data.setdefault(key3, [value3['value']])
            
    #print(company_data)                             
    columns = company_data.keys()



    df = pd.DataFrame.from_dict(company_data, orient='index')
    df = df.transpose()
    df = df.drop_duplicates(subset='dateyearend', keep='first', inplace=False)
    df.insert(0, 'Company', stock)
    return df

# %%
re = my_scraper('EXPN/EXPERIAN-PLC')
main_df = main_df.append(re)
main_df
# Out:
# https://www.londonstockexchange.com/stock/EXPN/EXPERIAN-PLC/fundamentals
#              Company dateyearend currency totaldividend taxes     revenue  \
# 0  EXPN/EXPERIAN-PLC  2015-03-31      USD        0.3925     -  4810000000
# 1  EXPN/EXPERIAN-PLC  2016-03-31      USD           0.4     -  4550000000
# 2  EXPN/EXPERIAN-PLC  2017-03-31      USD         0.415     -  4335000000
# 3  EXPN/EXPERIAN-PLC  2018-03-31      USD        0.4475     -  4662000000
# 4  EXPN/EXPERIAN-PLC  2019-03-31      USD         0.465     -  4861000000
#
#   provisionsforlosses profitforperiod pretaxprofit posttaxprofit  ...  \
# 0                   -       772000000   1001000000     746000000  ...
# 1                   -       752000000   1023000000     760000000  ...
# 2                   -       865000000   1067000000     808000000  ...
# 3                   -       815000000    986000000     837000000  ...
# 4                   -       701000000    954000000     698000000  ...
#
#   epsgrowthpercentual dividendcover revenuepershare pretaxprofitpershare  \
# 0              2.8646        1.9592          4.9232               1.0246
# 1             -0.7782        1.9975          4.7365               1.0649
# 2             17.4966        2.0843          4.6117               1.1351
# 3             -3.4745        2.0581           5.084               1.0752
# 4            -13.4983        1.6538          5.3772               1.0553
#
#   operatingmarging returnoncapitalemployed dividendyield  \
# 0          24.0541                 17.3724        2.3742
# 1          23.3187                 18.2086        2.2311
# 2          24.7982                 19.1503        2.0393
# 3          23.4878                 18.5373        2.0642
# 4          23.8017                 19.3884        1.7074
#
#   dividendpersharegrowth navpershare netgearing
# 0                 8.0325     -3.2748   112.8859
# 1                 3.0997     -3.3391   122.2772
# 2                 2.9302     -3.2516   112.2016
# 3                  3.871     -3.7224   128.3149
# 4                 7.8509     -3.6461   128.0242
#
# [5 rows x 53 columns]

# %% [markdown]
# ## Creating a list of companies to analyse

# %%
def my_lister(url):
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.212 Safari/537.36'}
    

    full_url = url

    #print(full_url)

    r = requests.get(full_url)
    soup = BeautifulSoup(r.text, 'lxml')
    data = json.loads(soup.select_one('#ng-lseg-state').string.replace('&q;','"'))
    #print(len(data['sortedComponents']['content']))
    bruh  = data['sortedComponents']
    companies_list = bruh['content'][2]['status']['childComponents'][0]['content']['ftseIndexInstruments']['value']
    #[1]['ftseIndexInstruments']
    companies = {}

    for i in companies_list:
        x = i['tidm']['value']
        y = i['issuername']['value']
        if '&a;' in y: 
            y = y.replace("&a;","&")
        y = y.replace(" ", "-")
        companies[x] = y
    return companies

# %%
numOfPages = [1,2,3,4,5,6]
full_companies_list = {}
url = 'https://www.londonstockexchange.com/indices/ftse-100/constituents/table?page={}'
for i in numOfPages:
    num = str(i)
    full_url = url.format(num)
    companies = my_lister(full_url)
    full_companies_list.update(companies)
    
#full_companies_list
full_companies_list.pop("ENT")
full_companies_list.pop("RKT")
full_companies_list
# Out:
# {'JET': 'JUST-EAT-TAKEAWAY.COM-N.V.',
#  'IAG': 'INTERNATIONAL-CONSOLIDATED-AIRLINES-GROUP-S.A.',
#  'OCDO': 'OCADO-GROUP-PLC',
#  'AVV': 'AVEVA-GROUP-PLC',
#  'SKG': 'SMURFIT-KAPPA-GROUP-PLC',
#  'CPG': 'COMPASS-GROUP-PLC',
#  'INF': 'INFORMA-PLC',
#  'RSW': 'RENISHAW-PLC',
#  'EXPN': 'EXPERIAN-PLC',
#  'HSBA': 'HSBC-HOLDINGS-PLC',
#  'AVST': 'AVAST-PLC',
#  'SMDS': 'SMITH-(DS)-PLC',
#  'WEIR': 'WEIR-GROUP-PLC',
#  'IHG': 'INTERCONTINENTAL-HOTELS-GROUP-PLC',
#  'RMV': 'RIGHTMOVE-PLC',
#  'AUTO': 'AUTO-TRADER-GROUP-PLC',
#  'LLOY': 'LLOYDS-BANKING-GROUP-PLC',
#  'ITRK': 'INTERTEK-GROUP-PLC',
#  'ADM': 'ADMIRAL-GROUP-PLC',
#  'SMT': 'SCOTTISH-MORTGAGE-INVESTMENT-TRUST-PLC',
#  'SSE': 'SSE-PLC',
#  'FLTR': 'FLUTTER-ENTERTAINMENT-PLC',
#  'JD.': 'JD-SPORTS-FASHION-PLC',
#  'PHNX': 'PHOENIX-GROUP-HOLDINGS-PLC',
#  'BARC': 'BARCLAYS-PLC',
#  'STAN': 'STANDARD-CHARTERED-PLC',
#  'ICP': 'INTERMEDIATE-CAPITAL-GROUP-PLC',
#  'PRU': 'PRUDENTIAL-PLC',
#  'HLMA': 'HALMA-PLC',
#  'ULVR': 'UNILEVER-PLC',
#  'HL.': 'HARGREAVES-LANSDOWN-PLC',
#  'SDR': 'SCHRODERS-PLC',
#  'LSEG': 'LONDON-STOCK-EXCHANGE-GROUP-PLC',
#  'KGF': 'KINGFISHER-PLC',
#  'FRES': 'FRESNILLO-PLC',
#  'BLND': 'BRITISH-LAND-COMPANY-PLC',
#  'WTB': 'WHITBREAD-PLC',
#  'MNDI': 'MONDI-PLC',
#  'IMB': 'IMPERIAL-BRANDS-PLC',
#  'NWG': 'NATWEST-GROUP-PLC',
#  'CRH': 'CRH-PLC',
#  'DGE': 'DIAGEO-PLC',
#  'SBRY': 'SAINSBURY-(J)-PLC',
#  'PSH': 'PERSHING-SQUARE-HOLDINGS-LTD',
#  'SLA': 'STANDARD-LIFE-ABERDEEN-PLC',
#  'SGE': 'SAGE-GROUP-PLC',
#  'NXT': 'NEXT-PLC',
#  'RTO': 'RENTOKIL-INITIAL-PLC',
#  'RSA': 'RSA-INSURANCE-GROUP-PLC',
#  'SPX': 'SPIRAX-SARCO-ENGINEERING-PLC',
#  'RR.': 'ROLLS-ROYCE-HOLDINGS-PLC',
#  'FERG': 'FERGUSON-PLC',
#  'REL': 'RELX-PLC',
#  'GSK': 'GLAXOSMITHKLINE-PLC',
#  'CCH': 'COCA-COLA-HBC-AG',
#  'STJ': 'ST.-JAMES&s;S-PLACE-PLC',
#  'PSON': 'PEARSON-PLC',
#  'BA.': 'BAE-SYSTEMS-PLC',
#  'UU.': 'UNITED-UTILITIES-GROUP-PLC',
#  'TW.': 'TAYLOR-WIMPEY-PLC',
#  'JMAT': 'JOHNSON-MATTHEY-PLC',
#  'BNZL': 'BUNZL-PLC',
#  'HIK': 'HIKMA-PHARMACEUTICALS-PLC',
#  'WPP': 'WPP-PLC',
#  'SGRO': 'SEGRO-PLC',
#  'MRO': 'MELROSE-INDUSTRIES-PLC',
#  'CRDA': 'CRODA-INTERNATIONAL-PLC',
#  'PSN': 'PERSIMMON-PLC',
#  'TSCO': 'TESCO-PLC',
#  'SVT': 'SEVERN-TRENT-PLC',
#  'BME': 'B&M-EUROPEAN-VALUE-RETAIL-S.A.',
#  'NG.': 'NATIONAL-GRID-PLC',
#  'BKG': 'BERKELEY-GROUP-HOLDINGS-(THE)-PLC',
#  'III': '3I-GROUP-PLC',
#  'POLY': 'POLYMETAL-INTERNATIONAL-PLC',
#  'LAND': 'LAND-SECURITIES-GROUP-PLC',
#  'BDEV': 'BARRATT-DEVELOPMENTS-PLC',
#  'BATS': 'BRITISH-AMERICAN-TOBACCO-PLC',
#  'DCC': 'DCC-PLC',
#  'EVR': 'EVRAZ-PLC',
#  'SN.': 'SMITH-&-NEPHEW-PLC',
#  'LGEN': 'LEGAL-&-GENERAL-GROUP-PLC',
#  'AV.': 'AVIVA-PLC',
#  'BP.': 'BP-PLC',
#  'BRBY': 'BURBERRY-GROUP-PLC',
#  'ABF': 'ASSOCIATED-BRITISH-FOODS-PLC',
#  'ANTO': 'ANTOFAGASTA-PLC',
#  'AZN': 'ASTRAZENECA-PLC',
#  'AHT': 'ASHTEAD-GROUP-PLC',
#  'RIO': 'RIO-TINTO-PLC',
#  'SMIN': 'SMITHS-GROUP-PLC',
#  'VOD': 'VODAFONE-GROUP-PLC',
#  'RDSA': 'ROYAL-DUTCH-SHELL-PLC',
#  'BHP': 'BHP-GROUP-PLC',
#  'MNG': 'M&G-PLC',
#  'BT.A': 'BT-GROUP-PLC',
#  'RDSB': 'ROYAL-DUTCH-SHELL-PLC',
#  'GLEN': 'GLENCORE-PLC',
#  'AAL': 'ANGLO-AMERICAN-PLC'}

# %%
for key, value in full_companies_list.items():
    stock = '{}/{}'
    stock = stock.format(key, value)
    print(stock)
    data = my_scraper(stock)
    main_df = main_df.append(data, ignore_index=True)
    #print(main_df)
    
main_df
# Out:
# JET/JUST-EAT-TAKEAWAY.COM-N.V.
# https://www.londonstockexchange.com/stock/JET/JUST-EAT-TAKEAWAY.COM-N.V./fundamentals
# IAG/INTERNATIONAL-CONSOLIDATED-AIRLINES-GROUP-S.A.
# https://www.londonstockexchange.com/stock/IAG/INTERNATIONAL-CONSOLIDATED-AIRLINES-GROUP-S.A./fundamentals
# OCDO/OCADO-GROUP-PLC
# https://www.londonstockexchange.com/stock/OCDO/OCADO-GROUP-PLC/fundamentals
# AVV/AVEVA-GROUP-PLC
# https://www.londonstockexchange.com/stock/AVV/AVEVA-GROUP-PLC/fundamentals
# SKG/SMURFIT-KAPPA-GROUP-PLC
# https://www.londonstockexchange.com/stock/SKG/SMURFIT-KAPPA-GROUP-PLC/fundamentals
# CPG/COMPASS-GROUP-PLC
# https://www.londonstockexchange.com/stock/CPG/COMPASS-GROUP-PLC/fundamentals
# INF/INFORMA-PLC
# https://www.londonstockexchange.com/stock/INF/INFORMA-PLC/fundamentals
# RSW/RENISHAW-PLC
# https://www.londonstockexchange.com/stock/RSW/RENISHAW-PLC/fundamentals
# EXPN/EXPERIAN-PLC
# https://www.londonstockexchange.com/stock/EXPN/EXPERIAN-PLC/fundamentals
# HSBA/HSBC-HOLDINGS-PLC
# https://www.londonstockexchange.com/stock/HSBA/HSBC-HOLDINGS-PLC/fundamentals
# AVST/AVAST-PLC
# https://www.londonstockexchange.com/stock/AVST/AVAST-PLC/fundamentals
# SMDS/SMITH-(DS)-PLC
# https://www.londonstockexchange.com/stock/SMDS/SMITH-(DS)-PLC/fundamentals
# WEIR/WEIR-GROUP-PLC
# https://www.londonstockexchange.com/stock/WEIR/WEIR-GROUP-PLC/fundamentals
# IHG/INTERCONTINENTAL-HOTELS-GROUP-PLC
# https://www.londonstockexchange.com/stock/IHG/INTERCONTINENTAL-HOTELS-GROUP-PLC/fundamentals
# RMV/RIGHTMOVE-PLC
# https://www.londonstockexchange.com/stock/RMV/RIGHTMOVE-PLC/fundamentals
# AUTO/AUTO-TRADER-GROUP-PLC
# https://www.londonstockexchange.com/stock/AUTO/AUTO-TRADER-GROUP-PLC/fundamentals
# LLOY/LLOYDS-BANKING-GROUP-PLC
# https://www.londonstockexchange.com/stock/LLOY/LLOYDS-BANKING-GROUP-PLC/fundamentals
# ITRK/INTERTEK-GROUP-PLC
# https://www.londonstockexchange.com/stock/ITRK/INTERTEK-GROUP-PLC/fundamentals
# ADM/ADMIRAL-GROUP-PLC
# https://www.londonstockexchange.com/stock/ADM/ADMIRAL-GROUP-PLC/fundamentals
# SMT/SCOTTISH-MORTGAGE-INVESTMENT-TRUST-PLC
# https://www.londonstockexchange.com/stock/SMT/SCOTTISH-MORTGAGE-INVESTMENT-TRUST-PLC/fundamentals
# SSE/SSE-PLC
# https://www.londonstockexchange.com/stock/SSE/SSE-PLC/fundamentals
# FLTR/FLUTTER-ENTERTAINMENT-PLC
# https://www.londonstockexchange.com/stock/FLTR/FLUTTER-ENTERTAINMENT-PLC/fundamentals
# JD./JD-SPORTS-FASHION-PLC
# https://www.londonstockexchange.com/stock/JD./JD-SPORTS-FASHION-PLC/fundamentals
# PHNX/PHOENIX-GROUP-HOLDINGS-PLC
# https://www.londonstockexchange.com/stock/PHNX/PHOENIX-GROUP-HOLDINGS-PLC/fundamentals
# BARC/BARCLAYS-PLC
# https://www.londonstockexchange.com/stock/BARC/BARCLAYS-PLC/fundamentals
# STAN/STANDARD-CHARTERED-PLC
# https://www.londonstockexchange.com/stock/STAN/STANDARD-CHARTERED-PLC/fundamentals
# ICP/INTERMEDIATE-CAPITAL-GROUP-PLC
# https://www.londonstockexchange.com/stock/ICP/INTERMEDIATE-CAPITAL-GROUP-PLC/fundamentals
# PRU/PRUDENTIAL-PLC
# https://www.londonstockexchange.com/stock/PRU/PRUDENTIAL-PLC/fundamentals
# HLMA/HALMA-PLC
# https://www.londonstockexchange.com/stock/HLMA/HALMA-PLC/fundamentals
# ULVR/UNILEVER-PLC
# https://www.londonstockexchange.com/stock/ULVR/UNILEVER-PLC/fundamentals
# HL./HARGREAVES-LANSDOWN-PLC
# https://www.londonstockexchange.com/stock/HL./HARGREAVES-LANSDOWN-PLC/fundamentals
# SDR/SCHRODERS-PLC
# https://www.londonstockexchange.com/stock/SDR/SCHRODERS-PLC/fundamentals
# LSEG/LONDON-STOCK-EXCHANGE-GROUP-PLC
# https://www.londonstockexchange.com/stock/LSEG/LONDON-STOCK-EXCHANGE-GROUP-PLC/fundamentals
# KGF/KINGFISHER-PLC
# https://www.londonstockexchange.com/stock/KGF/KINGFISHER-PLC/fundamentals
# FRES/FRESNILLO-PLC
# https://www.londonstockexchange.com/stock/FRES/FRESNILLO-PLC/fundamentals
# BLND/BRITISH-LAND-COMPANY-PLC
# https://www.londonstockexchange.com/stock/BLND/BRITISH-LAND-COMPANY-PLC/fundamentals
# WTB/WHITBREAD-PLC
# https://www.londonstockexchange.com/stock/WTB/WHITBREAD-PLC/fundamentals
# MNDI/MONDI-PLC
# https://www.londonstockexchange.com/stock/MNDI/MONDI-PLC/fundamentals
# IMB/IMPERIAL-BRANDS-PLC
# https://www.londonstockexchange.com/stock/IMB/IMPERIAL-BRANDS-PLC/fundamentals
# NWG/NATWEST-GROUP-PLC
# https://www.londonstockexchange.com/stock/NWG/NATWEST-GROUP-PLC/fundamentals
# CRH/CRH-PLC
# https://www.londonstockexchange.com/stock/CRH/CRH-PLC/fundamentals
# DGE/DIAGEO-PLC
# https://www.londonstockexchange.com/stock/DGE/DIAGEO-PLC/fundamentals
# SBRY/SAINSBURY-(J)-PLC
# https://www.londonstockexchange.com/stock/SBRY/SAINSBURY-(J)-PLC/fundamentals
# PSH/PERSHING-SQUARE-HOLDINGS-LTD
# https://www.londonstockexchange.com/stock/PSH/PERSHING-SQUARE-HOLDINGS-LTD/fundamentals
# SLA/STANDARD-LIFE-ABERDEEN-PLC
# https://www.londonstockexchange.com/stock/SLA/STANDARD-LIFE-ABERDEEN-PLC/fundamentals
# SGE/SAGE-GROUP-PLC
# https://www.londonstockexchange.com/stock/SGE/SAGE-GROUP-PLC/fundamentals
# NXT/NEXT-PLC
# https://www.londonstockexchange.com/stock/NXT/NEXT-PLC/fundamentals
# RTO/RENTOKIL-INITIAL-PLC
# https://www.londonstockexchange.com/stock/RTO/RENTOKIL-INITIAL-PLC/fundamentals
# RSA/RSA-INSURANCE-GROUP-PLC
# https://www.londonstockexchange.com/stock/RSA/RSA-INSURANCE-GROUP-PLC/fundamentals
# SPX/SPIRAX-SARCO-ENGINEERING-PLC
# https://www.londonstockexchange.com/stock/SPX/SPIRAX-SARCO-ENGINEERING-PLC/fundamentals
# RR./ROLLS-ROYCE-HOLDINGS-PLC
# https://www.londonstockexchange.com/stock/RR./ROLLS-ROYCE-HOLDINGS-PLC/fundamentals
# FERG/FERGUSON-PLC
# https://www.londonstockexchange.com/stock/FERG/FERGUSON-PLC/fundamentals
# REL/RELX-PLC
# https://www.londonstockexchange.com/stock/REL/RELX-PLC/fundamentals
# GSK/GLAXOSMITHKLINE-PLC
# https://www.londonstockexchange.com/stock/GSK/GLAXOSMITHKLINE-PLC/fundamentals
# CCH/COCA-COLA-HBC-AG
# https://www.londonstockexchange.com/stock/CCH/COCA-COLA-HBC-AG/fundamentals
# STJ/ST.-JAMES&s;S-PLACE-PLC
# https://www.londonstockexchange.com/stock/STJ/ST.-JAMES&s;S-PLACE-PLC/fundamentals
# PSON/PEARSON-PLC
# https://www.londonstockexchange.com/stock/PSON/PEARSON-PLC/fundamentals
# BA./BAE-SYSTEMS-PLC
# https://www.londonstockexchange.com/stock/BA./BAE-SYSTEMS-PLC/fundamentals
# UU./UNITED-UTILITIES-GROUP-PLC
# https://www.londonstockexchange.com/stock/UU./UNITED-UTILITIES-GROUP-PLC/fundamentals
# TW./TAYLOR-WIMPEY-PLC
# https://www.londonstockexchange.com/stock/TW./TAYLOR-WIMPEY-PLC/fundamentals
# JMAT/JOHNSON-MATTHEY-PLC
# https://www.londonstockexchange.com/stock/JMAT/JOHNSON-MATTHEY-PLC/fundamentals
# BNZL/BUNZL-PLC
# https://www.londonstockexchange.com/stock/BNZL/BUNZL-PLC/fundamentals
# HIK/HIKMA-PHARMACEUTICALS-PLC
# https://www.londonstockexchange.com/stock/HIK/HIKMA-PHARMACEUTICALS-PLC/fundamentals
# WPP/WPP-PLC
# https://www.londonstockexchange.com/stock/WPP/WPP-PLC/fundamentals
# SGRO/SEGRO-PLC
# https://www.londonstockexchange.com/stock/SGRO/SEGRO-PLC/fundamentals
# MRO/MELROSE-INDUSTRIES-PLC
# https://www.londonstockexchange.com/stock/MRO/MELROSE-INDUSTRIES-PLC/fundamentals
# CRDA/CRODA-INTERNATIONAL-PLC
# https://www.londonstockexchange.com/stock/CRDA/CRODA-INTERNATIONAL-PLC/fundamentals
# PSN/PERSIMMON-PLC
# https://www.londonstockexchange.com/stock/PSN/PERSIMMON-PLC/fundamentals
# TSCO/TESCO-PLC
# https://www.londonstockexchange.com/stock/TSCO/TESCO-PLC/fundamentals
# SVT/SEVERN-TRENT-PLC
# https://www.londonstockexchange.com/stock/SVT/SEVERN-TRENT-PLC/fundamentals
# BME/B&M-EUROPEAN-VALUE-RETAIL-S.A.
# https://www.londonstockexchange.com/stock/BME/B&M-EUROPEAN-VALUE-RETAIL-S.A./fundamentals
# NG./NATIONAL-GRID-PLC
# https://www.londonstockexchange.com/stock/NG./NATIONAL-GRID-PLC/fundamentals
# BKG/BERKELEY-GROUP-HOLDINGS-(THE)-PLC
# https://www.londonstockexchange.com/stock/BKG/BERKELEY-GROUP-HOLDINGS-(THE)-PLC/fundamentals
# III/3I-GROUP-PLC
# https://www.londonstockexchange.com/stock/III/3I-GROUP-PLC/fundamentals
# POLY/POLYMETAL-INTERNATIONAL-PLC
# https://www.londonstockexchange.com/stock/POLY/POLYMETAL-INTERNATIONAL-PLC/fundamentals
# LAND/LAND-SECURITIES-GROUP-PLC
# https://www.londonstockexchange.com/stock/LAND/LAND-SECURITIES-GROUP-PLC/fundamentals
# BDEV/BARRATT-DEVELOPMENTS-PLC
# https://www.londonstockexchange.com/stock/BDEV/BARRATT-DEVELOPMENTS-PLC/fundamentals
# BATS/BRITISH-AMERICAN-TOBACCO-PLC
# https://www.londonstockexchange.com/stock/BATS/BRITISH-AMERICAN-TOBACCO-PLC/fundamentals
# DCC/DCC-PLC
# https://www.londonstockexchange.com/stock/DCC/DCC-PLC/fundamentals
# EVR/EVRAZ-PLC
# https://www.londonstockexchange.com/stock/EVR/EVRAZ-PLC/fundamentals
# SN./SMITH-&-NEPHEW-PLC
# https://www.londonstockexchange.com/stock/SN./SMITH-&-NEPHEW-PLC/fundamentals
# LGEN/LEGAL-&-GENERAL-GROUP-PLC
# https://www.londonstockexchange.com/stock/LGEN/LEGAL-&-GENERAL-GROUP-PLC/fundamentals
# AV./AVIVA-PLC
# https://www.londonstockexchange.com/stock/AV./AVIVA-PLC/fundamentals
# BP./BP-PLC
# https://www.londonstockexchange.com/stock/BP./BP-PLC/fundamentals
# BRBY/BURBERRY-GROUP-PLC
# https://www.londonstockexchange.com/stock/BRBY/BURBERRY-GROUP-PLC/fundamentals
# ABF/ASSOCIATED-BRITISH-FOODS-PLC
# https://www.londonstockexchange.com/stock/ABF/ASSOCIATED-BRITISH-FOODS-PLC/fundamentals
# ANTO/ANTOFAGASTA-PLC
# https://www.londonstockexchange.com/stock/ANTO/ANTOFAGASTA-PLC/fundamentals
# AZN/ASTRAZENECA-PLC
# https://www.londonstockexchange.com/stock/AZN/ASTRAZENECA-PLC/fundamentals
# AHT/ASHTEAD-GROUP-PLC
# https://www.londonstockexchange.com/stock/AHT/ASHTEAD-GROUP-PLC/fundamentals
# RIO/RIO-TINTO-PLC
# https://www.londonstockexchange.com/stock/RIO/RIO-TINTO-PLC/fundamentals
# SMIN/SMITHS-GROUP-PLC
# https://www.londonstockexchange.com/stock/SMIN/SMITHS-GROUP-PLC/fundamentals
# VOD/VODAFONE-GROUP-PLC
# https://www.londonstockexchange.com/stock/VOD/VODAFONE-GROUP-PLC/fundamentals
# RDSA/ROYAL-DUTCH-SHELL-PLC
# https://www.londonstockexchange.com/stock/RDSA/ROYAL-DUTCH-SHELL-PLC/fundamentals
# BHP/BHP-GROUP-PLC
# https://www.londonstockexchange.com/stock/BHP/BHP-GROUP-PLC/fundamentals
# MNG/M&G-PLC
# https://www.londonstockexchange.com/stock/MNG/M&G-PLC/fundamentals
# BT.A/BT-GROUP-PLC
# https://www.londonstockexchange.com/stock/BT.A/BT-GROUP-PLC/fundamentals
# RDSB/ROYAL-DUTCH-SHELL-PLC
# https://www.londonstockexchange.com/stock/RDSB/ROYAL-DUTCH-SHELL-PLC/fundamentals
# GLEN/GLENCORE-PLC
# https://www.londonstockexchange.com/stock/GLEN/GLENCORE-PLC/fundamentals
# AAL/ANGLO-AMERICAN-PLC
# https://www.londonstockexchange.com/stock/AAL/ANGLO-AMERICAN-PLC/fundamentals
#                      Company dateyearend currency totaldividend taxes  \
# 0          EXPN/EXPERIAN-PLC  2015-03-31      USD        0.3925     -
# 1          EXPN/EXPERIAN-PLC  2016-03-31      USD           0.4     -
# 2          EXPN/EXPERIAN-PLC  2017-03-31      USD         0.415     -
# 3          EXPN/EXPERIAN-PLC  2018-03-31      USD        0.4475     -
# 4          EXPN/EXPERIAN-PLC  2019-03-31      USD         0.465     -
# ...                      ...         ...      ...           ...   ...
# 1373  AAL/ANGLO-AMERICAN-PLC  2016-12-31      USD             -     -
# 1374  AAL/ANGLO-AMERICAN-PLC  2017-12-31      USD          1.02     -
# 1375  AAL/ANGLO-AMERICAN-PLC  2018-12-31      USD             1     -
# 1376  AAL/ANGLO-AMERICAN-PLC  2019-12-31      USD          1.09     -
# 1377  AAL/ANGLO-AMERICAN-PLC  2020-12-31      USD             1     -
#
#           revenue provisionsforlosses profitforperiod pretaxprofit  \
# 0      4810000000                   -       772000000   1001000000
# 1      4550000000                   -       752000000   1023000000
# 2      4335000000                   -       865000000   1067000000
# 3      4662000000                   -       815000000    986000000
# 4      4861000000                   -       701000000    954000000
# ...           ...                 ...             ...          ...
# 1373  21378000000                   -      1926000000   2346000000
# 1374  26243000000                   -      4059000000   4938000000
# 1375  27610000000                   -      4373000000   5461000000
# 1376  29870000000                   -      4582000000   5757000000
# 1377  30902000000                   -      3328000000   5361000000
#
#      posttaxprofit  ... epsgrowthpercentual dividendcover revenuepershare  \
# 0        746000000  ...              2.8646        1.9592          4.9232
# 1        760000000  ...             -0.7782        1.9975          4.7365
# 2        808000000  ...             17.4966        2.0843          4.6117
# 3        837000000  ...             -3.4745        2.0581           5.084
# 4        698000000  ...            -13.4983        1.6538          5.3772
# ...            ...  ...                 ...           ...             ...
# 1373    1648000000  ...                   -             -         16.5525
# 1374    3492000000  ...            100.5479        2.4314         20.5827
# 1375    3645000000  ...             12.9032           2.8         21.7573
# 1376    4193000000  ...              0.3571         2.578           23.65
# 1377    3225000000  ...             -40.022          1.69         24.8729
#
#      pretaxprofitpershare operatingmarging returnoncapitalemployed  \
# 0                  1.0246          24.0541                 17.3724
# 1                  1.0649          23.3187                 18.2086
# 2                  1.1351          24.7982                 19.1503
# 3                  1.0752          23.4878                 18.5373
# 4                  1.0553          23.8017                 19.3884
# ...                   ...              ...                     ...
# 1373               1.8165           7.7931                  4.9803
# 1374               3.8729          21.0685                  16.473
# 1375               4.3034          21.9812                  17.979
# 1376               4.5582          20.6763                 18.1386
# 1377               4.3151          18.2221                 15.0022
#
#      dividendyield dividendpersharegrowth navpershare netgearing
# 0           2.3742                 8.0325     -3.2748   112.8859
# 1           2.2311                 3.0997     -3.3391   122.2772
# 2           2.0393                 2.9302     -3.2516   112.2016
# 3           2.0642                  3.871     -3.7224   128.3149
# 4           1.7074                 7.8509     -3.6461   128.0242
# ...            ...                    ...         ...        ...
# 1373             -                      -      11.267    37.4316
# 1374        4.9509                      -     13.9889    18.1569
# 1375        4.4699               114.2857     14.5994    10.1873
# 1376        3.8001                10.4167     15.8314    17.7011
# 1377        3.0328               -34.8954     18.3418    23.1955
#
# [1378 rows x 53 columns]

# %%
# Out:
# Empty DataFrame
# Columns: [Company, dateyearend, currency, totaldividend, taxes, revenue, provisionsforlosses, profitforperiod, pretaxprofit, posttaxprofit, otheroperatingexpenses, othernonoperatingincome, operatingprofitLoss, operatingexpenses, noninterestincome, noninterestexpense, netinterestbeforeprovisions, netinterestafterprovisions, netinterest, minorityinterests, interestincome, interestexpense, grossprofit, equityholderofparent, epsbasiccontinuinganddiscontinued, epsbasic, deprecationamortization, costofrevenue, benefitsandoperatingexpenses, belowlineadjustments, totalassets, totalnoncurrentassets, totalcurrentassets, totalliabilities, totalnoncurrentliabilities, totalcurrentliabilities, netassets, totalequity, shareholdersfunds, bsminorityinterests, retainedearnings, peratio, peg, epsgrowthpercentual, dividendcover, revenuepershare, pretaxprofitpershare, operatingmarging, returnoncapitalemployed, dividendyield, dividendpersharegrowth, navpershare, netgearing]
# Index: []
#
# [0 rows x 53 columns]
